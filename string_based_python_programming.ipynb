# %% [markdown]
# <a href="https://colab.research.google.com/github/SUGITHA2004/Login/blob/main/string_based_python_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1)reserve a string

a="codewriter"
print(a[::-1])
# Out:
# retirwedoc

# %%
# 2)count the number of vowels and consonants

vowels=['a','e','i','o','u']
consonants=['b','c','d','f','g','h','j','k','l','m','n','p','q','r','s','t','v','w','x','y','z']
print(len(vowels))
print(len(consonants))
# Out:
# 5
# 21

# %%
# 3)if check it is palindrom are not

a=input("Enter a charchter: ")
if a==a[::-1]:
  print("Its a palindrom")
else:
  print("Its not a palindrom")
# Out:
# Enter a charchter: mackbook
# Its not a palindrom

# %%
# 4)Find the frequency of each character in a string

a=input("Enter a String: ")
for i in a:
  print(i,a.count(i))
# Out:
# Enter a String: Ajaysugitha
# A 1
# j 1
# a 2
# y 1
# s 1
# u 1
# g 1
# i 1
# t 1
# h 1
# a 2

# %%
# 5)Remove all duplicate character from a string


a = input("Enter a String: ")


result = "".join(set(a))

print(result)
# Out:
# Enter a String: apple
# elpa

# %%
# 6)Replace all space using "-"

a=input("Enter a  String: ")
print(a.replace(" ","-"))
# Out:
# Enter a  String: i want to become a data analytis
# i-want-to-become-a-data-analytis-

# %%
# 7)Find largest word in a sentence

a=input("Enter a sentence: ")

print(max(a.split(),key=len))
# Out:
# Enter a sentence:  i am a codewriter
# codewriter

# %%
# 8)Count how many times a substring appears in a string

a=input("Enter a String: ")
b=input("Enter a substring: ")
print(a.count(b))
# Out:
# Enter a String: apple is a teasty furit
# Enter a substring: furit
# 1

# %%
# 9)Convert the  first letter in Uppercase

a=input("Enter a String: ")
print(a.title())
# Out:
# Enter a String: program
# Program

# %%
# 10) two strings are anagrams(litrly same word ah  or same spling ah ierukum like listen,slient)

string1=input("Enter a String: ")
string2=input("Enter a String: ")

if string1!=string2:
  print("Its Anagrams")
else:
  print("Its not Anagrams")
# Out:
# Enter a String: listen
# Enter a String: slient
# Its Anagrams
